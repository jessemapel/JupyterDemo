# %% [markdown]
# ### Network Analysis

# %%
import networkx as nx
from networkx.algorithms import bipartite
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt

# %% [markdown]
# ## Graphs
# In this demo we will build a graph from the Apollo 15 landing site control network

# %%
data_file="apollo.csv"

# %% [markdown]
# First we need to import the csv as before

# %%
df = pd.read_csv(data_file)

# %% [markdown]
# ### Graph Generation
# Now we will create a NetworkX bipartite graph from the Panda's data frame.
# Using our data frame we can decide how we want to associate the data from our csv with the different parts of the graph
#
# * [cnettable documentation](https://isis.astrogeology.usgs.gov/Application/presentation/Tabbed/cnettable/cnettable.html)

# %%
pd.set_option('display.max_columns',200)
df.head(3)
# Out:
#   ControlPointId PointType ChooserName             DateTime  EditLock  \
# 0      SG0001747      Free    seedgrid  2017-05-15T09:29:55         0
# 1      SG0001747      Free    seedgrid  2017-05-15T09:29:55         0
# 2      SG0001748      Free    seedgrid  2017-05-15T10:31:07         0
#
#    Ignored AprioriSurfacePointSource AprioriSurfacePointSourceFile  \
# 0        0         AverageOfMeasures                           NaN
# 1        0         AverageOfMeasures                           NaN
# 2        0         AverageOfMeasures                           NaN
#
#   AprioriRadiusSource AprioriRadiusSourceFile     AprioriX   AprioriY  \
# 0   AverageOfMeasures                     NaN  1539.998109  49.980759
# 1   AverageOfMeasures                     NaN  1539.998109  49.980759
# 2   AverageOfMeasures                     NaN  1536.442625  49.902033
#
#      AprioriZ  AprioriXSigma  AprioriYSigma  AprioriZSigma  AprioriLatitude  \
# 0  798.721357       0.002003       0.002937       0.003872        27.401227
# 1  798.721357       0.002003       0.002937       0.003872        27.401227
# 2  805.788001       0.001694       0.002295       0.003214        27.662361
#
#    AprioriLongitude  AprioriLocalRadius  AprioriLatitudeSigma  \
# 0          1.858886         1735.525298              0.000144
# 1          1.858886         1735.525298              0.000144
# 2          1.860252         1735.638343              0.000120
#
#    AprioriLongitudeSigma  AprioriLocalRadiusSigma  \
# 0               0.000109                 0.000006
# 1               0.000109                 0.000006
# 2               0.000086                 0.000005
#
#    AprioriLatitudeSigmaDistance  AprioriLongitudeSigmaDistance  AdjustedX  \
# 0                      0.004368                       0.003723        NaN
# 1                      0.004368                       0.003723        NaN
# 2                      0.003634                       0.002934        NaN
#
#    AdjustedY  AdjustedZ  AdjustedXSigma  AdjustedYSigma  AdjustedZSigma  \
# 0        NaN        NaN             NaN             NaN             NaN
# 1        NaN        NaN             NaN             NaN             NaN
# 2        NaN        NaN             NaN             NaN             NaN
#
#    AdjustedLatitude  AdjustedLongitude  AdjustedLocalRadius  \
# 0               NaN                NaN                  NaN
# 1               NaN                NaN                  NaN
# 2               NaN                NaN                  NaN
#
#    AdjustedLatitudeSigma  AdjustedLongitudeSigma  AdjustedLocalRadiusSigma  \
# 0                    NaN                     NaN                       NaN
# 1                    NaN                     NaN                       NaN
# 2                    NaN                     NaN                       NaN
#
#    AdjustedLatitudeSigmaDistance  AdjustedLongitudeSigmaDistance  \
# 0                            NaN                             NaN
# 1                            NaN                             NaN
# 2                            NaN                             NaN
#
#    MinimumResidual  MaximumResidual  AverageResidual  MinimumSampleResidual  \
# 0         0.232364         1.300336         0.766350              -1.296299
# 1         0.232364         1.300336         0.766350              -1.296299
# 2         1.856701         2.488413         2.172557              -0.780359
#
#    MaximumSamlpeResidual  MinimumLineResidual  MaximumLineResidual  \
# 0               0.210965            -0.102383             0.097402
# 1               0.210965            -0.102383             0.097402
# 2               2.449068            -1.684749            -0.440754
#
#    MaximumSampleShift  MinimumSampleShift  AverageSampleShift  \
# 0                 NaN                 NaN                 NaN
# 1                 NaN                 NaN                 NaN
# 2                 NaN                 NaN                 NaN
#
#    MaximumLineShift  MinimumLineShift  AverageLineShift  MaximumPixelShift  \
# 0               NaN               NaN               NaN                NaN
# 1               NaN               NaN               NaN                NaN
# 2               NaN               NaN               NaN                NaN
#
#    MinimumPixelShift  AveragePixelShift  MinimumPixelZScore  \
# 0                NaN                NaN            6.164302
# 1                NaN                NaN            6.164302
# 2                NaN                NaN            4.521453
#
#    AveragePixelZScore  MaximumGoodnessOfFit  MinimumGoodnessOfFit  \
# 0           -4.903468              0.780150              0.735902
# 1           -4.903468              0.780150              0.735902
# 2           -3.106660              0.830115              0.800980
#
#    AverageGoodnessOfFit  AprioriLine  AprioriSample ChooserName.1  \
# 0              0.758026          NaN            NaN        jigsaw
# 1              0.758026          NaN            NaN        jigsaw
# 2              0.815548          NaN            NaN        jigsaw
#
#                           CubeSerialNumber           DateTime.1      Line  \
# 0  APOLLO15/METRIC/1971-07-31T14:01:40.346  2015-10-14T16:22:26  1178.050
# 1  APOLLO15/METRIC/1971-07-31T14:02:03.751  2015-10-14T16:22:26  1168.040
# 2  APOLLO15/METRIC/1971-07-31T14:01:40.346  2015-10-14T16:22:26   900.877
#
#    LineResidual  LineSigma    Sample  SampleResidual  SampleSigma  \
# 0      0.097402        NaN   276.863        0.210965          NaN
# 1     -0.102383        NaN  1539.590       -1.296300          NaN
# 2     -0.440754        NaN   275.558        2.449070          NaN
#
#    ResidualMagnitude         MeasureType  \
# 0           0.232364  RegisteredSubPixel
# 1           1.300340  RegisteredSubPixel
# 2           2.488410  RegisteredSubPixel
#
#                                             Filename     Sample.1  \
# 0  /work/projects/IPCE/IpceData/Apollo15/AS15-M-0...   276.862901
# 1  /work/projects/IPCE/IpceData/Apollo15/AS15-M-0...  1539.587537
# 2  /work/projects/IPCE/IpceData/Apollo15/AS15-M-0...   275.557713
#
#         Line.1  PixelValue  RightAscension  Declination  \
# 0  1178.047966   21568.002      270.524771   -22.470969
# 1  1168.037696   20264.551      253.905140   -22.167382
# 2   900.877458   21469.609      269.714636   -19.586176
#
#    PlanetocentricLatitude  PlanetographicLatitude  PositiveEast360Longitude  \
# 0               27.370230               27.370230                  1.920663
# 1               27.372157               27.372157                  1.914317
# 2               27.630687               27.630687                  1.922900
#
#    PositiveEast180Longitude  PositiveWest360Longitude  \
# 0                  1.920663                358.079337
# 1                  1.914317                358.085683
# 2                  1.922900                358.077100
#
#    PositiveWest180Longitude  BodyFixedCoordinateX  BodyFixedCoordinateY  \
# 0                 -1.920663           1540.258806             51.651735
# 1                 -1.914317           1540.237786             51.480240
# 2                 -1.922900           1536.698454             51.592409
#
#    BodyFixedCoordinateZ   LocalRadius  SampleResolution  LineResolution  \
# 0            797.827519  1.735394e+06          9.046942        9.046942
# 1            797.879385  1.735395e+06          7.982859        7.982859
# 2            804.868035  1.735487e+06          9.252652        9.252652
#
#    SpacecraftPositionX  SpacecraftPositionY  SpacecraftPositionZ  \
# 0          1653.216689           130.247163           798.178842
# 1          1654.701216            91.958731           799.831076
# 2          1653.216689           130.247163           798.178842
#
#    SpacecraftAzimuth  SlantDistance  TargetCenterDistance  \
# 0          33.570752     137.611221           1840.429083
# 1          52.849335     121.425673           1840.169088
# 2          37.652008     140.740239           1840.429083
#
#    SubSpacecraftLatitude  SubSpacecraftLongitude  SpacecraftAltitude  \
# 0              25.702075                4.504691          101.761268
# 1              25.763080                3.180896          104.789807
# 2              25.702075                4.504691          101.761268
#
#    OffNadirAngle  SubSpacecraftGroundAzimuth  SunPositionX  SunPositionY  \
# 0      38.842188                  125.230558  4.614361e+07  1.447657e+08
# 1      29.390152                  144.568065  4.615198e+07  1.447630e+08
# 2      40.304420                  129.307249  4.614361e+07  1.447657e+08
#
#     SunPositionZ  SubSolarAzimuth  SolarDistance  SubSolarLatitude  \
# 0  609774.910316         6.515734       1.015673          0.229939
# 1  609759.449193         6.937924       1.015674          0.229933
# 2  609774.910316         6.414550       1.015673          0.229939
#
#    SubSolarLongitude  SubSolarGroundAzimuth      Phase  Incidence   Emission  \
# 0          72.320480              99.086030  37.490939  72.558365  41.692864
# 1          72.317172              99.085103  52.843573  72.561336  31.357966
# 2          72.320480              99.167862  38.400077  72.597721  43.311337
#
#    NorthAzimuth  EphemerisTime                          UTC  LocalSolarTime  \
# 0    269.690918  -8.969111e+08  1971-07-31T14:01:40.3459999        7.306679
# 1    268.908304  -8.969110e+08      1971-07-31T14:02:03.751        7.306476
# 2    269.876058  -8.969111e+08  1971-07-31T14:01:40.3459999        7.306828
#
#    SolarLongitude  LookDirectionBodyFixedX  LookDirectionBodyFixedY  \
# 0      171.716895                -0.820848                -0.571141
# 1      171.717156                -0.942663                -0.333360
# 2      171.716895                -0.827896                -0.558865
#
#    LookDirectionBodyFixedZ  LookDirectionJ2000X  LookDirectionJ2000Y  \
# 0                -0.002553             0.008463            -0.924035
# 1                -0.016073            -0.256737            -0.889787
# 2                 0.047529            -0.004692            -0.942127
#
#    LookDirectionJ2000Z  LookDirectionCameraX  LookDirectionCameraY  \
# 0            -0.382215              0.527973             -0.343891
# 1            -0.377314              0.302751             -0.387630
# 2            -0.335224              0.517435             -0.392278
#
#    LookDirectionCameraZ  ObliqueDetectorResolution  ObliquePixelResolution  \
# 0             -0.776520                  12.115558               12.115558
# 1             -0.870680                   9.348346                9.348346
# 2             -0.760512                  12.716027               12.716027
#
#    ObliqueLineResolution  ObliqueSampleResolution
# 0              12.115558                12.115558
# 1               9.348346                 9.348346
# 2              12.716027                12.716027

# %% [markdown]
# Based on looking at out data we want to make control points and images nodes and control measures nodes.
#
# On control point nodes we'll add the ground point and the point type.
#
# On image nodes we'll add the cube serial number.
#
# On control measure edges we'll add the measure location, the measure residual, and the computed photometric angles.

# %%
B = nx.Graph()
for index, row in df.iterrows():
    B.add_node(row['ControlPointId'],
               bipartite=0,
               point_type=row['PointType'],
               lat=row['AprioriLatitude'],
               lon=row['AprioriLongitude'],
               rad=row['AprioriLocalRadius'])
    B.add_node(row['CubeSerialNumber'],
               bipartite=1)
    B.add_edge(row['ControlPointId'],
               row['CubeSerialNumber'],
               measure_type=row['MeasureType'],
               sample=row['Sample'],
               line=row['Line'],
               sample_residual=row['SampleResidual'],
               line_residual=row['LineResidual'],
               phase=row['Phase'],
               incidence=row['Incidence'],
               emission=row['Emission'],
               image=row['CubeSerialNumber'])

# %%
points = {n for n, d in B.nodes(data=True) if d['bipartite']==0}
images = {n for n, d in B.nodes(data=True) if d['bipartite']==1}

# %% [markdown]
# From the control network we know there are 4 images, 440 control points, and 1119 control measures so we can dynamically check that we have all of those.

# %%
print('Images: {}\nPoints: {}\nMeasures: {}'.format(len(images), len(points),len(B.edges())))
# Out:
# Images: 4
# Points: 440
# Measures: 1119

# %% [markdown]
# ### Drawing Graphs
# Now that we have our graph let's look at it

# %%
nx.draw(B)
plt.show()

# %% [markdown]
# That's super ugly so let's try drawing it another way

# %%
pos = dict()
ratio = len(points)/len(images)
pos.update( (n, ((i+0.5)*ratio, 0)) for i, n in enumerate(images) )
pos.update( (n, (i, 0.5)) for i, n in enumerate(points) )
nx.draw(B, pos=pos)
plt.show()

# %%
images
# Out:
# {'APOLLO15/METRIC/1971-07-31T14:00:53.547',
#  'APOLLO15/METRIC/1971-07-31T14:01:16.947',
#  'APOLLO15/METRIC/1971-07-31T14:01:40.346',
#  'APOLLO15/METRIC/1971-07-31T14:02:03.751'}

# %% [markdown]
# Now we can see the images are separate from the control points but that still looks terrible!
#
# Let's try some other settings
#
# * [colors](https://matplotlib.org/examples/color/colormaps_reference.html)
# * [drawing options](https://networkx.github.io/documentation/stable/reference/generated/networkx.drawing.nx_pylab.draw_networkx.html#networkx.drawing.nx_pylab.draw_networkx)

# %%
def average_color(colors):
    average = [sum(color) / len(color) for color in zip(*colors)]
    return tuple(average)

# %%
cmap = matplotlib.cm.get_cmap('Greens')
node_cmap = matplotlib.cm.get_cmap('Reds')

num_images = len(images)
image_colors = dict()
image_colors.update( (image, cmap((i+1)/(num_images+1))) for i, image in enumerate(images) )
image_node_colors = dict()
image_node_colors.update( (image, node_cmap((i+1)/(num_images+1))) for i, image in enumerate(images) )

edge_colors = [image_colors[image] for _, _, image in B.edges.data('image')]

node_colors = [image_node_colors[node] if node in images else average_color([image_colors[image] for image in B.neighbors(node)]) for node in B.nodes]

# %%
nx.draw(B,
        #edge_color=edge_colors,
        node_color=node_colors,
        alpha=0.75)
plt.show()

# %% [markdown]
# That's better but still not great. Let's try plotting the image and points separately

# %%
image_graph = bipartite.projected_graph(B, images)
nx.draw(image_graph)
plt.show()

# %%
point_graph = bipartite.projected_graph(B, points)
nx.draw(point_graph)
plt.show()

# %% [markdown]
# Let's try making the points graph look a bit nicer

# %%
free_cmap = matplotlib.cm.get_cmap('Greens')
constrained_cmap = matplotlib.cm.get_cmap('Reds')
point_node_colors = [cmap(B.degree(node)/4) if B.node[node]['point_type'] == 'Free' else constrained_cmap(B.degree(node)/4) for node in point_graph.nodes]

point_pos = dict()
point_pos.update((node ,(point_graph.node[node]['lat'], point_graph.node[node]['lon'])) for node in point_graph.nodes)

# %%
nx.draw(point_graph,
        pos=point_pos,
        node_color=point_node_colors,
        edgelist=[],
        alpha=0.75)
plt.show()
