# %% [markdown]
# # What are Jupyter Notebooks?

# %% [markdown]
# > The Jupyter Notebook is an open-source web application that allows you to create and share documents that contain live code, equations, visualizations and narrative text. Uses include: data cleaning and transformation, numerical simulation, statistical modeling, data visualization, machine learning, and much more.
# > -- [Project Jupyter](http://jupyter.org/)

# %% [markdown]
# Jupyter Notebooks support text cells formatted with [Markdown](https://github.com/adam-p/markdown-here/wiki/Markdown-Cheatsheet#blockquotes) and code cells that run Python code

# %%
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# # What can you do with a Jupyter Notebook?

# %% [markdown]
# Basically anything you can do with Python!
#
# * Import Modules
# * Execute Code
# * Generate Figures
# * Write functions

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.widgets import Slider

# %%
# %matplotlib notebook
x = np.linspace(0, 1, 200)
y = np.sin(x * 2 * np.pi)

plt.plot(x, y)
plt.axes([0, 1, -1, 1])
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
def my_polynomial(x):
    return 2*x**2 + x - 1

# %%
for x in np.linspace(1,10,10):
    print('Input: {}\nOutput: {}\n'.format(x, my_polynomial(x)))
# Out:
# Input: 1.0
# Output: 2.0
#
# Input: 2.0
# Output: 9.0
#
# Input: 3.0
# Output: 20.0
#
# Input: 4.0
# Output: 35.0
#
# Input: 5.0
# Output: 54.0
#
# Input: 6.0
# Output: 77.0
#
# Input: 7.0
# Output: 104.0
#
# Input: 8.0
# Output: 135.0
#
# Input: 9.0
# Output: 170.0
#
# Input: 10.0
# Output: 209.0
